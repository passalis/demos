# %% [markdown]
# ## Face Recognition

# %% [markdown]
# We can also combine multiple OpenDR tools to perform more complex tasks. In this tutorial, we will combine face detection and face recongition tools to perform face recognition using a web cam.
#
# Let's import some tools:

# %%
import cv2
# %matplotlib inline
from matplotlib import pyplot as plt
import numpy as np
from utils import VideoReader

# %% [markdown]
# Let's start by initializing the face recognition tool:

# %%
from opendr.perception.face_recognition import FaceRecognitionLearner

recognizer = FaceRecognitionLearner(device='cuda', backbone='mobilefacenet')

# %%
recognizer.download(path=".")
recognizer.load('opendr_face_backbone')
# Out:
# Model downloaded
# Loading backbone 'mobilefacenet'
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /tmp/ipykernel_24169/4111420066.py in <module>
#       1 recognizer.download(path=".")
# ----> 2 recognizer.load('opendr_face_backbone')
#
# ~/Desktop/demos/src/opendr/perception/face_recognition/face_recognition_learner.py in load(self, path)
#     785         if self.mode in ['backbone_only', 'head_only', 'finetune']:
#     786             print("Loading backbone '{}'".format(self.backbone))
# --> 787             self.__load_backbone(path)
#     788         elif self.network_head == 'classifier' and self.mode == 'full':
#     789             print("Loading backbone '{}' and head '{}'".format(self.backbone, self.network_head))
#
# ~/Desktop/demos/src/opendr/perception/face_recognition/face_recognition_learner.py in __load_backbone(self, path)
#     805         else:
#     806             if os.path.exists(os.path.join(path, 'backbone_' + self.backbone + '.pth')):
# --> 807                 self.__create_model(num_class=0)
#     808                 self.backbone_model.load_state_dict(torch.load(
#     809                     os.path.join(path, 'backbone_' + self.backbone + '.pth'), map_location=torch.device(self.device)))
#
# ~/Desktop/demos/src/opendr/perception/face_recognition/face_recognition_learner.py in __create_model(self, num_class)
#     145                              'mobilefacenet': MobileFaceNet()}
#     146             backbone = backbone_dict[self.backbone]
# --> 147             self.backbone_model = backbone.to(self.device)
#     148         # Create the head architecture
#     149         if self.mode != 'backbone_only':
#
# ~/Desktop/demos/venv/lib/python3.8/site-packages/torch/nn/modules/module.py in to(self, *args, **kwargs)
#     610             return t.to(device, dtype if t.is_floating_point() else None, non_blocking)
#     611
# --> 612         return self._apply(convert)
#     613
#     614     def register_backward_hook(
#
# ~/Desktop/demos/venv/lib/python3.8/site-packages/torch/nn/modules/module.py in _apply(self, fn)
#     357     def _apply(self, fn):
#     358         for module in self.children():
# --> 359             module._apply(fn)
#     360
#     361         def compute_should_use_set_data(tensor, tensor_applied):
#
# ~/Desktop/demos/venv/lib/python3.8/site-packages/torch/nn/modules/module.py in _apply(self, fn)
#     357     def _apply(self, fn):
#     358         for module in self.children():
# --> 359             module._apply(fn)
#     360
#     361         def compute_should_use_set_data(tensor, tensor_applied):
#
# ~/Desktop/demos/venv/lib/python3.8/site-packages/torch/nn/modules/module.py in _apply(self, fn)
#     379                 # `with torch.no_grad():`
#     380                 with torch.no_grad():
# --> 381                     param_applied = fn(param)
#     382                 should_use_set_data = compute_should_use_set_data(param, param_applied)
#     383                 if should_use_set_data:
#
# ~/Desktop/demos/venv/lib/python3.8/site-packages/torch/nn/modules/module.py in convert(t)
#     608             if convert_to_format is not None and t.dim() == 4:
#     609                 return t.to(device, dtype if t.is_floating_point() else None, non_blocking, memory_format=convert_to_format)
# --> 610             return t.to(device, dtype if t.is_floating_point() else None, non_blocking)
#     611
#     612         return self._apply(convert)
#
# ~/Desktop/demos/venv/lib/python3.8/site-packages/torch/cuda/__init__.py in _lazy_init()
#     170         # This function throws if there's a driver initialization error, no GPUs
#     171         # are found or any other error occurs
# --> 172         torch._C._cuda_init()
#     173         # Some of the queued calls may reentrantly call _lazy_init();
#     174         # we need to just return without initializing in that case.
#
# RuntimeError: CUDA unknown error - this may be due to an incorrectly set up environment, e.g. changing env variable CUDA_VISIBLE_DEVICES after program start. Setting the available devices to be zero.

# %% [markdown]
# Then we need to create a database of faces to recognize. This can be done very easily just by placing the face images into folders according to the subject to be recognized:

# %%
# %ls persons
# Out:
#  nick/       'Person 2'/  'Person 4'/  'Person 6'/
# 'Person 1'/  'Person 3'/  'Person 5'/

# %%
# %ls persons/Person\ 4
# Out:
# 1.jpg  2.jpg

# %% [markdown]
# Let's check a person's image:

# %%
from os.path import join
image_path = join("persons", "Person 4", "2.jpg")
img = cv2.imread(image_path)
plt.imshow(img[:, :, [2, 1, 0]])

# %% [markdown]
# Check our saved image

# %%
image_path = join("persons", "nick", "1.jpg")
img = cv2.imread(image_path)
plt.imshow(img[:, :, [2, 1, 0]])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_24169/3247300918.py in <module>
#       1 image_path = join("persons", "nick", "1.jpg")
#       2 img = cv2.imread(image_path)
# ----> 3 plt.imshow(img[:, :, [2, 1, 0]])
#
# TypeError: 'NoneType' object is not subscriptable

# %% [markdown]
# After collecting our images we need to build the recognition database:

# %%
recognizer.fit_reference("persons", save_path="database.pkl")

# %% [markdown]
# We are now ready to perform face recognition. First, we will grab a frame from the camera, perform face detection and then perform face recognition. To this end, we first need to initialize the face recognizer:

# %%
from opendr.perception.object_detection_2d import RetinaFaceLearner
from opendr.perception.object_detection_2d.datasets.transforms import BoundingBoxListToNumpyArray
from opendr.perception.object_detection_2d.utils.vis_utils import draw_bounding_boxes

learner = RetinaFaceLearner(backbone='resnet', device='cuda')
learner.download(".", mode="pretrained")
learner.load("./retinaface_resnet")

# %% [markdown]
# We are now ready to build the inference loop as before:

# %%
image_provider = VideoReader(0)
for counter, img in enumerate(image_provider):

    boxes = learner.infer(img, threshold=0.6)
    # If we have detected a face
    if len(boxes.data) > 0:
        # Crop it
        bbox = BoundingBoxListToNumpyArray()(boxes)[0][:4].astype(np.int)
        face_img = img[bbox[1]:bbox[3],bbox[0]:bbox[2], :]

        # Recognize the cropped image
        results = recognizer.infer(face_img)

        # Plot the results
        if results.confidence is not None and results.confidence > 0.5:
            cv2.putText(img, results.description , (bbox[0], max(bbox[1]-10, 0)),  cv2.FONT_HERSHEY_SIMPLEX, 0.8, (0, 255, 0), 1)
            cv2.rectangle(img, (bbox[0], bbox[1]), (bbox[2], bbox[3]), (0, 255, 0), 2)            
        else:
            cv2.putText(img, "Not found", (bbox[0], max(bbox[1]-10, 0)),  cv2.FONT_HERSHEY_SIMPLEX, 0.8, (0, 0, 255), 1)
            cv2.rectangle(img, (bbox[0], bbox[1]), (bbox[2], bbox[3]), (0, 0, 255), 2)
            
    cv2.imshow('Result', img)
    if cv2.waitKey(1) == ord('q'):
        break

cv2.destroyAllWindows()
image_provider.close()
